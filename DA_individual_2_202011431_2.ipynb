# %% [markdown]
# # 1. Library & Data import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'indv2_2.csv')
df.head(3)
# Out:
#    Column1         업체명 카테고리                                           메뉴    맛  \
# 0        0  전주석쇠불고기-본점   한식            파절이매콤통삼겹（2~3인）（공기밥2＋김치찌개＋밑반찬＋쌈）/1  5.0
# 1        1  전주석쇠불고기-본점   한식  통삼겹살 2人（고기＋공기밥2＋김치찌개＋쌈＋밑반찬）/1(추가 선택(고기 추가))  5.0
# 2        2  전주석쇠불고기-본점   한식                통삼겹살 2人（고기＋공기밥2＋김치찌개＋쌈＋밑반찬）/1  NaN
#
#      양   배달                                                 리뷰        date  \
# 0  5.0  5.0                          자주시켜먹는단골집인데항상변치않고맛있습니다!!!  2017-12-06
# 1  5.0  5.0  배달시간도오래걸리지않고,양이적을거같아서고기추가를했는데..안해도됐었네요ㅋㅋ.맛도이정도...  2017-09-30
# 2  NaN  NaN                                                 굿굿  2017-09-23
#
#    numbering  total
# 0          0    5.0
# 1          1    5.0
# 2          2    4.5

# %%
df_numbering_total = df[['numbering', 'total']]
df_numbering_total
# Out:
#        numbering  total
# 0              0    5.0
# 1              1    5.0
# 2              2    4.5
# 3              3    5.0
# 4              4    5.0
# ...          ...    ...
# 27853      28912    4.5
# 27854      28913    4.5
# 27855      28914    4.5
# 27856      28915    4.5
# 27857      28916    4.5
#
# [27858 rows x 2 columns]

# %%
df_origin_ver = pd.read_csv(r'data_review.csv')
df_origin_ver['numbering'] = 0

for i in range(len(df_origin_ver)):
    df_origin_ver.iloc[i, -1] = i    
    
df_origin_ver
# Out:
#               업체명 카테고리                                                 메뉴  \
# 0      전주석쇠불고기-본점   한식                  파절이매콤통삼겹（2~3인）（공기밥2＋김치찌개＋밑반찬＋쌈）/1
# 1      전주석쇠불고기-본점   한식        통삼겹살 2人（고기＋공기밥2＋김치찌개＋쌈＋밑반찬）/1(추가 선택(고기 추가))
# 2      전주석쇠불고기-본점   한식                      통삼겹살 2人（고기＋공기밥2＋김치찌개＋쌈＋밑반찬）/1
# 3      전주석쇠불고기-본점   한식  통삼겹（小／500g）（냉열무국수 or 냉열무우동 or 비빔열무국수＋쌈）/1(메뉴 선...
# 4      전주석쇠불고기-본점   한식                       통삼겹（3~4인）（김치찌개＋공기밥3＋밑반찬＋쌈）/1
# ...           ...  ...                                                ...
# 28912          동강   중식                                                NaN
# 28913          동강   중식                                                NaN
# 28914          동강   중식                                                NaN
# 28915          동강   중식                                                NaN
# 28916          동강   중식                                                NaN
#
#          맛    양   배달                                                 리뷰  \
# ...

# %%
df_fin = pd.merge(df_origin_ver, df_numbering_total, left_on = 'numbering', right_on = 'numbering', how = 'inner')
df_fin
# Out:
#               업체명 카테고리                                                 메뉴  \
# 0      전주석쇠불고기-본점   한식                  파절이매콤통삼겹（2~3인）（공기밥2＋김치찌개＋밑반찬＋쌈）/1
# 1      전주석쇠불고기-본점   한식        통삼겹살 2人（고기＋공기밥2＋김치찌개＋쌈＋밑반찬）/1(추가 선택(고기 추가))
# 2      전주석쇠불고기-본점   한식                      통삼겹살 2人（고기＋공기밥2＋김치찌개＋쌈＋밑반찬）/1
# 3      전주석쇠불고기-본점   한식  통삼겹（小／500g）（냉열무국수 or 냉열무우동 or 비빔열무국수＋쌈）/1(메뉴 선...
# 4      전주석쇠불고기-본점   한식                       통삼겹（3~4인）（김치찌개＋공기밥3＋밑반찬＋쌈）/1
# ...           ...  ...                                                ...
# 27853          동강   중식                                                NaN
# 27854          동강   중식                                                NaN
# 27855          동강   중식                                                NaN
# 27856          동강   중식                                                NaN
# 27857          동강   중식                                                NaN
#
#          맛    양   배달                                                 리뷰  \
# ...

# %%
df = df_fin[['리뷰', 'total']]
df
# Out:
#                                                       리뷰  total
# 0                          자주시켜먹는 단골집인데 항상변치않고 맛있습니다! !!    5.0
# 1      배달 시간도 오래걸리지 않고, 양이 적을거 같아서 고기 추가를 했는데..안해도 됐었...    5.0
# 2                                                     굿굿    4.5
# 3                                             배달도빠르고맛나요ㅁ    5.0
# 4      찌개와 통삼겹 맛있는 5찬. 많이 먹는편이라 3인분짜리 주문했는데... 배터지는줄 ...    5.0
# ...                                                  ...    ...
# 27853                                                좋아요    4.5
# 27854                                              맛있ㅇㅓ욧    4.5
# 27855                                               맛이게다    4.5
# 27856  여기 맛있어요 이근처 탕수육은 냄새?ㅜㅜ돼지냄새?나는 곳이 너무 많은데 여긴안그래요...    4.5
# 27857                                 맛있어요 또시켜먹어야지 추천할께요    4.5
#
# [27858 rows x 2 columns]

# %%
df = df.rename(columns={"total" : "rating"})
df
# Out:
#                                                       리뷰  rating
# 0                          자주시켜먹는 단골집인데 항상변치않고 맛있습니다! !!     5.0
# 1      배달 시간도 오래걸리지 않고, 양이 적을거 같아서 고기 추가를 했는데..안해도 됐었...     5.0
# 2                                                     굿굿     4.5
# 3                                             배달도빠르고맛나요ㅁ     5.0
# 4      찌개와 통삼겹 맛있는 5찬. 많이 먹는편이라 3인분짜리 주문했는데... 배터지는줄 ...     5.0
# ...                                                  ...     ...
# 27853                                                좋아요     4.5
# 27854                                              맛있ㅇㅓ욧     4.5
# 27855                                               맛이게다     4.5
# 27856  여기 맛있어요 이근처 탕수육은 냄새?ㅜㅜ돼지냄새?나는 곳이 너무 많은데 여긴안그래요...     4.5
# 27857                                 맛있어요 또시켜먹어야지 추천할께요     4.5
#
# [27858 rows x 2 columns]

# %%
df.to_csv(r'C:\Users\moon_\OneDrive - konkuk.ac.kr\바탕 화면/indv3.csv')

# %% [markdown]
# # 2. Dataset 살펴보기

# %%
df.shape #dimension
# Out:
# (27858, 2)

# %%
#information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27858 entries, 0 to 27857
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰      27858 non-null  object
#  1   rating  27858 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 652.9+ KB

# %%
# 결측치
df.isnull().sum()
# Out:
# 리뷰        0
# rating    0
# dtype: int64

# %%
df[df['리뷰'].str.contains('★')]
# Out:
#                                                       리뷰    rating
# 3823                                                 존맛★  3.666667
# 3854   정말맛있당♥핫불고기 처음인데 깜짝놀랬어요 피자가매워봤자 했는데 굽★볼케이노보다 더매...  4.500000
# 5475   음...치킨박사겸 매니아 인데 순살양념&간장양념 을 먹은 강민★입니다. 브랜드로 손...  4.500000
# 10681                       앞으로 뿌링클 자주 먹을 것 같아요 ★ 맛있네요 !  4.500000
# 13267                      짜장 짬뽕은 ★★★ 탕수육은 ★★★☆ 친절 ★★★★★  4.500000
# 13379  맛이써여 !!! 서비스로 군만두도두시고!!!짱입니더ㅓㅠㅠㅠㅠ 군만두먹고싶었는데.제....  4.500000
# 14103  맛 서비스 모두 만족입니다 포장센스(뽁뽁이)에 놀라고 배달원분이 오분후 도착이라고 ...  4.000000
# 14183  리뷰통해서 처음시켜 먹어봤는데요 ~양도 푸짐하고 족발위에 마늘소스 부어서 먹으면 깔...  5.000000
# 14503        불족발 시켰는데 양이 살짝 아쉬웠지만 비린내도안나고 너무맛있었어요!! 강추★★  4.500000
# 16573  너무많이 시켜먹어서 요기요포인트 쌓인거 장난아님ㅋ그래도 귀찮아도 매번 리뷰남겨요ㅎ ...  4.500000
# 16868  동생이 먹고싶다고해서 또 도야로 주문했습니당 불족을 하도 강추해서 주문했는데 진짜 ...  3.666667
# 21062                                             ★★★★★?  3.333333
# 22518  배달도 빠르고 정말 맛있어욯ㅎㅎㅎ 매운 걸 못먹어서 순한 맛을 선택했는데 정말 하나...  5.000000
# ...

# %%
df[df['리뷰'].str.contains('ㅁ')]
# Out:
#                                                       리뷰    rating
# 3                                             배달도빠르고맛나요ㅁ  5.000000
# 4107   ㅁ맛도있고 무엇보다 배달이40분이였나그정도걸린다고문자왔는데15분인가20분만에와서 기...  5.000000
# 4184                                   ㅣㅈ그븧ㅁㄹㅇㅂㅈㄱ딪ㆍㅇㆍㅇㆍㄷ  5.000000
# 11331                     요레요레 먹었는데 기름기가 느껴지지 않고 깔끔해서 정ㅁ  4.500000
# 11516                                     맛있었읍니다.ㅁ2ㅏㅅ있어요  4.500000
# 12799  여자사장인지 전화와서 ㅈㄴ싸가지없게 말투하고 배달온양반은 대답도없이 문쾅쾅하더니 음...  1.333333
# 12859                                               맛있ㅇㅁ  4.500000
# 13654                                       뿔어서옴 근데맛잇ㅇㄷㅁ  4.500000
# 15666                                      ㅁㆍㅅ있어요 무가좀적은듯  4.000000
# 16798                                       ㅁ맛있게 잘 먹었습니다  4.500000
# 17319                        무채 좀 더 달라는 말을 무시한거 빼곤 맛있ㅇㄷㅁ  4.500000
# 17722  우선 메인인 족발이 워낙 만족스러워서 가장 ㅁ좋았어요 사이드 메뉴가 저희 가족 입맛...  5.000000
# 18165                                               맛잇ㅇㅁ  4.500000
# ...

# %% [markdown]
# 리뷰 column을 살펴보면 특수문자, 모음이 존재하는 경우가 있다. 해당 data는 Text mining을 적용할 의미가 없기에, 정규표현식을 사용하여 제거하도록 한다.

# %% [markdown]
# # 3. Korean text data Preprocessing

# %% [markdown]
# ## 3-1. 정규 표현식 적용

# %%
# !pip install konlpy

# %%
# 정규 표현식 함수 정의

import re

def apply_regular_expression(text):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')  # 한글 추출 규칙: 띄어 쓰기(1 개)를 포함한 한글
    result = hangul.sub('', text)  # 위에 설정한 "hangul"규칙을 "text"에 적용(.sub)시킴
    return result

# %%
df['리뷰'][20869]
# Out:
# '우오..ㅁㅐ워요ㅋㅋ 원래 매운거 조아하는데 .. 먹다가 땀났슈ㅎㅎ 닭도 부드럽고 닭발도 쫄깃? 근디 먹다가 두개가 뼈 덜발라졌슈ㅎㅎ'

# %%
apply_regular_expression(df['리뷰'][20869])
# Out:
# '우오ㅁㅐ워요ㅋㅋ 원래 매운거 조아하는데  먹다가 땀났슈ㅎㅎ 닭도 부드럽고 닭발도 쫄깃 근디 먹다가 두개가 뼈 덜발라졌슈ㅎㅎ'

# %% [markdown]
# ## 3-2. 한국어 형태소 분석 - 명사 단위

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
# !pip install --upgrade pip
# !pip install konlpy

# %%
apply_regular_expression(df['리뷰'][20869])
# Out:
# '우오ㅁㅐ워요ㅋㅋ 원래 매운거 조아하는데  먹다가 땀났슈ㅎㅎ 닭도 부드럽고 닭발도 쫄깃 근디 먹다가 두개가 뼈 덜발라졌슈ㅎㅎ'

# %%
df[df['리뷰'].str.contains('오시')]
# Out:
#                                                       리뷰    rating
# 489    배달 하시는분이 카드기 안된다고 문앞에서 씩씩되시면서 짜증 짜증을 내면서 그러고 나...  4.500000
# 576                 꼬끼꼬끼 넘넘 맛있어요 ㅎㅎㅎ 배달도 정확히 오시공 진철까지 ㅎㅎ  4.500000
# 577                  배달도 소요시간보다 빨리오시고... 고기도 맛나고 찬도 맛있네요  4.500000
# 822    남친이랑 맥주먹으면서 천천히 먹자 햇는데 이레댓어요ㆍ 갑자기 피자 먹고싶어서 한번시...  5.000000
# 1413   안타까운 마음에 글을 남깁니다. 저는 대략 일년반?정도 마스터피자를 먹던 손님입니다...  5.000000
# ...                                                  ...       ...
# 26590  하...오늘은 고난의 연속인가!!!!!! (7500원 가격에 비해 돈까스 김보다 작...  5.000000
# 26846  어제도 시켜먹었네요.. 대체적으로 친정에서 시켜먹는 중국집 보다 맛있대요. 부모님 ...  5.000000
# 27120        배달 왜케 빠른지..ㄷㄷ 시키고 씻어야지하고 화장실 왔는데 배달오시네여....  4.666667
# 27181  다신 안시켜요 면은 다 뿔었고 쟁반짜장 속 오징어나 새우는 다 익지도 않았는지 비렸...  5.000000
# 27689  굴짬뽕.세트지만탕수육은 너무맛났음요 짜장면은좀싱거운듯. 대기시간보다십분일찍오시고 배...  4.500000
#
# [87 rows x 2 columns]
