# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'data_week13.csv')
df
# Out:
#      caseno  SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0         1          5.1         3.5          1.4         0.2     setosa
# 1         2          4.9         3.0          1.4         0.2     setosa
# 2         3          4.7         3.2          1.3         0.2     setosa
# 3         4          4.6         3.1          1.5         0.2     setosa
# 4         5          5.0         3.6          1.4         0.2     setosa
# ..      ...          ...         ...          ...         ...        ...
# 145     146          6.7         3.0          5.2         2.3  virginica
# 146     147          6.3         2.5          5.0         1.9  virginica
# 147     148          6.5         3.0          5.2         2.0  virginica
# 148     149          6.2         3.4          5.4         2.3  virginica
# 149     150          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 6 columns]

# %%
X = df.iloc[:, 1:-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: Species, Length: 150, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %%
dt_clf = DecisionTreeClassifier(max_depth = 5)
dt_clf.fit(X_train, y_train)
print('max depth가 5인 경우, decision tree의 정확도: ',dt_clf.score(X_test, y_test))
# Out:
# max depth가 5인 경우, decision tree의 정확도:  0.8666666666666667

# %%
dt_clf4 = DecisionTreeClassifier(max_depth = 4)
dt_clf4.fit(X_train, y_train)
print('max depth가 5인 경우, decision tree의 정확도: ',dt_clf4.score(X_test, y_test))
# Out:
# max depth가 5인 경우, decision tree의 정확도:  0.9333333333333333

# %%
dt_clf3 = DecisionTreeClassifier(max_depth = 3)
dt_clf3.fit(X_train, y_train)
print('max depth가 5인 경우, decision tree의 정확도: ',dt_clf3.score(X_test, y_test))
# Out:
# max depth가 5인 경우, decision tree의 정확도:  0.9333333333333333

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure( figsize=(20,15) )
tree.plot_tree(dt_clf4, 
               class_names=list(set(y)),
               feature_names=X.columns.to_list(),
               impurity=True, filled=True,
               rounded=True)
# Out:
# [Text(0.3181818181818182, 0.9, 'PetalWidth <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]\nclass = virginica'),
#  Text(0.22727272727272727, 0.7, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]\nclass = virginica'),
#  Text(0.4090909090909091, 0.7, 'PetalWidth <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]\nclass = versicolor'),
#  Text(0.18181818181818182, 0.5, 'PetalLength <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]\nclass = versicolor'),
#  Text(0.09090909090909091, 0.3, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]\nclass = versicolor'),
#  Text(0.2727272727272727, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = setosa'),
#  Text(0.6363636363636364, 0.5, 'PetalWidth <= 1.75\ngini = 0.136\nsamples = 41\nvalue = [0, 3, 38]\nclass = setosa'),
#  Text(0.45454545454545453, 0.3, 'SepalLength <= 5.45\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]\nclass = versicolor'),
#  Text(0.36363636363636365, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = setosa'),
#  Text(0.5454545454545454, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(0.8181818181818182, 0.3, 'PetalLength <= 4.85\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]\nclass = setosa'),
#  Text(0.7272727272727273, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = setosa'),
#  Text(0.9090909090909091, 0.1, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = setosa')]

# %%
plt.figure( figsize=(20,15) )
tree.plot_tree(dt_clf3, 
               class_names=list(set(y)),
               feature_names=X.columns.to_list(),
               impurity=True, filled=True,
               rounded=True)
# Out:
# [Text(0.375, 0.875, 'PetalLength <= 2.45\ngini = 0.667\nsamples = 120\nvalue = [41, 40, 39]\nclass = virginica'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]\nclass = virginica'),
#  Text(0.5, 0.625, 'PetalWidth <= 1.55\ngini = 0.5\nsamples = 79\nvalue = [0, 40, 39]\nclass = versicolor'),
#  Text(0.25, 0.375, 'PetalLength <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]\nclass = versicolor'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]\nclass = versicolor'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = setosa'),
#  Text(0.75, 0.375, 'PetalWidth <= 1.75\ngini = 0.136\nsamples = 41\nvalue = [0, 3, 38]\nclass = setosa'),
#  Text(0.625, 0.125, 'gini = 0.5\nsamples = 4\nvalue = [0, 2, 2]\nclass = versicolor'),
#  Text(0.875, 0.125, 'gini = 0.053\nsamples = 37\nvalue = [0, 1, 36]\nclass = setosa')]
